# %%
##使用TextRank算法获取用户兴趣标签
import math
import numpy as np 
win = 5 #窗口大小

# %%
##导入uid list
def load_uid():
    uid_list = []
    with open('../../data/uid.txt','r',encoding = 'utf-8') as f1:
        while True:
            line = f1.readline()
            if not line:
                break
            uid_list.append(line.strip())
        f1.close()
    return uid_list

# %%
##读取训练集样本
def load_train():
    wid = []
    filename = '../../data/train/'+str(uid)+'.dat'
    with open(filename,'r',encoding='utf-8') as f:
        while True:
            line = f.readline()
            if not line:
                break
            line = eval(line)
            w = line['id']
            userid = line['userid']
            if userid == uid:
                wid.append(w)
            else:
                break
        f.close()
    return wid

# %%
##读取用户训练集微博文本
def load_text():
    text = {}
    filename = '../../data/text/after_filter/'+str(uid)+'.dat'
    with open(filename,'r',encoding='utf-8') as f:
        while True:
            line = f.readline().strip()
            if not line:
                break
            line = line.split(':')
            words = line[1].split(' ')
            if line[0] in wid:
                text[line[0]] = words
            else:
                break
        f.close()
    return text

# %%
##导入单词TF-IDF得分
def load_tfidf():
    tfidf = {}
    filename = './user_interest_tag/'+ str(uid) + '_usertag_by_tfidf.dat'
    with open(filename,'r',encoding = 'utf-8') as f:
        while True:
            line = f.readline().strip()
            if not line:
                break
            line = line.split('\t')
            tfidf[line[0]] = float(line[1])
        f.close()
    return tfidf

# %%
##初始化边权重
def init_weight():
    weight = {}
    for w in text.keys():
        n = len(text[w])
        for i in range(0,n):
            word = text[w][i]
            if word not in weight:
                weight[word] = {}
            for j in range(max(0,i-win+1),min(i+win,n)):
                if i==j:
                    continue
                word2 = text[w][j]
                if word2 not in weight[word]:
                    weight[word][word2] = 0
                weight[word][word2] += 1
                if word2 not in weight:
                    weight[word2] = {}
                if word not in weight[word2]:
                    weight[word2][word] = 0
                weight[word2][word] +=1
    return weight

# %%
##初始化结点输出值
def init_out(weight):
    out = {}
    for w1 in tfidf.keys():
        out[w1] = 0
        for w2 in weight[w1]:
            out[w1] += weight[w1][w2]
    return out

# %%
def textRank():
    d = 0.85  ##阻尼系数
    iterator = 100  ##迭代次数
    weight = init_weight()
    out = init_out(weight)
    value = {}
    for item in tfidf.keys():
        value[item] = (1-d) * tfidf[item]
    for i in range(0,iterator):##迭代次数
        for item in weight.keys():
            sum = 0 
            for word in weight[item]:
                sum += (weight[item][word] * value[word])/out[word]
            #value[item] = (1-d) * tfidf[item] + d * sum
            value[item] = (1-d)  + d * sum * (tfidf[item] + 1 )
    return value

# %%
# 提取数据集的单元素集合（大小为1的候选集的集合）
def createC1(dataSet):
    C1 = set()
    for transaction in dataSet:
        for item in transaction:
            C1.add(item)
    C1 = list(C1)
    C1.sort()
    # frozenset能作为key
    return map(lambda x:frozenset([x]), C1)

# 计算Ck中每项的支持度并过滤
def scanD(D, Ck, minSupport):
    ssCnt = {}
    for can in Ck:
        for tid in D:
            if can.issubset(tid):
                if can not in ssCnt:
                    ssCnt[can] = 1
                else:
                    ssCnt[can] += 1
    retList = [] # Lk
    supportData = {} # 支持度
    for key in ssCnt:
        support = ssCnt[key]
        if support >= minSupport:
            retList.append(key) # 阈值过滤
        supportData[key] = support
    return retList, supportData

# %%
# 构造下一个候选集Ck 
def aprioriGen(Lk, k):
    retList = []
    lenLk = len(Lk)
    for i in range(lenLk):
        for j in range(i+1, lenLk):
            L1 = list(Lk[i])[:k-2]; L2 = list(Lk[j])[:k-2]
            L1.sort(); L2.sort()
            if L1 == L2: # 如果它们前k-2项相同
                retList.append(Lk[i] | Lk[j]) # 合并
    return retList

def apriori(dataSet, minSupport=3):
    C1 = createC1(dataSet)
    D = dataSet
    #D = map(set, dataSet)
    L1, supportData = scanD(D, C1, minSupport)
    L = [L1]
    k = 2
    while len(L[k-2])>0:
        Ck = aprioriGen(L[k-2], k)
        Lk, supK = scanD(D, Ck, minSupport) # 扫描并过滤
        supportData.update(supK)
        L.append(Lk)
        k += 1
    return L, supportData

# %%
# 计算可信度
def calcConf(freqSet, H, supportData, br1, minConf=0.7):
    prunedH = []
    for conseq in H:
        if  len(freqSet - conseq) >1:
            continue
        conf = supportData[freqSet] / supportData[freqSet - conseq]
        if conf >= minConf: # 过滤
            # print "{0} --> {1} conf:{2}".format(freqSet - conseq, conseq, conf)
            br1.append((freqSet - conseq, conseq, conf))
            prunedH.append(conseq)
    return prunedH

def rulesFromConseq(freqSet, H, supportData, br1, minConf=0.7):
    m = len(H[0])
    if len(freqSet) > m+1:
        Hmp1 = aprioriGen(H, m+1)
        Hmp1 = calcConf(freqSet, Hmp1, supportData, br1, minConf)
        if len(Hmp1)>1:
            rulesFromConseq(freqSet, Hmp1, supportData, br1, minConf)

def generateRules(L, supportData, minConf=0.8):
    bigRuleList = []
    for i in range(1, len(L)):
        for freqSet in L[i]:
            H1 = [frozenset([item]) for item in freqSet]
            if i>1:
                rulesFromConseq(freqSet, H1, supportData, bigRuleList, minConf)
            else:
                calcConf(freqSet, H1, supportData, bigRuleList, minConf)
    return bigRuleList

# %%
##基于关联规则扩展成词串
def keyword_extend():
    user_tag = sorted(value.items(),key=lambda x:x[1],reverse=True)
    key = []##选取前20个关键词扩展
    word_fre = {} ##词频
    corr = {} ##词共现
    extend = {} ##扩展词串
    for i in range(0,20):
        key.append(user_tag[i][0])
        extend[user_tag[i][0]] = set()
        extend[user_tag[i][0]].add(user_tag[i][0])
    
    data = []
    for w in text.keys():
        num = len(text[w])
        tmp = set()
        for i in range(0,num):
            if text[w][i] in key:
                tmp.add(text[w][i])
        if len(tmp) < 2:
            continue
        data.append(tmp)
    
    ##关联规则aprioir算法
    L,supportData = apriori(data,2) ##L：频繁集
    rule = generateRules(L, supportData, minConf=0.7) ##关联规则 
    #print(supportData)
    print("关联规则：")
    print(rule)
    
    for item in rule:
        w1 = list(item[0])[0]
        w2 = list(item[1])
        for w in w2:
            extend[w1].add(w)
    #print(extend)
    result = {}
    for w1 in key:
        if len(extend[w1]) == 1: ##没有扩展单词
            result[w1] = value[w1]
            continue
        s = sorted(extend[w1])  ##扩展词串排序
        st=''
        for w2 in s:
            st += w2 + ',' ##单词用逗号分隔
        st = st[0:-1]
        if st not in result:
            result[st] = value[w1]
        else:
            result[st] += value[w1]
    #print(result)
    return result

# %%
##保存结果(对照组，未扩展词串)
def save_result():
    user_tag = sorted(result.items(),key=lambda x:x[1],reverse=True)
    filename = './user_interest_tag/'+ str(uid) + '_usertag_by_textrank.dat'
    with open(filename,'w',encoding = 'utf-8') as f:
        for item in user_tag:
            f.write(item[0] + '\t'  + str(item[1]) + '\n')
        f.close()

# %%
##保存结果(实验组，扩展词串)
def save_result_extend():
    user_tag = sorted(result.items(),key=lambda x:x[1],reverse=True)
    filename = './user_interest_tag/'+ str(uid) + '_usertag_by_textrank_extend.dat'
    with open(filename,'w',encoding = 'utf-8') as f:
        for item in user_tag:
            f.write(item[0] + '\t'  + str(item[1]) + '\n')
        f.close()

# %%
if __name__ == '__main__':
    uid_list = load_uid()
    for uid in uid_list:
        print("用户"+str(uid))
        uid = int(uid)
        wid = load_train()  ##读取训练集
        text = load_text() ##读取微博文本
        tfidf = load_tfidf() ##读取TF-IDF因子
        value = textRank() ##TextRank算法计算得分
        result = value
        save_result() ##保存结果，对照组
        result = keyword_extend() ##兴趣标签扩展
        save_result_extend() ##保存结果,扩展词串
# Out:
# 用户3927298812
# 关联规则：
# [(frozenset({'callumturner'}), frozenset({'卡'}), 1.0), (frozenset({'卡'}), frozenset({'callumturner'}), 0.75), (frozenset({'地球'}), frozenset({'moss'}), 0.75), (frozenset({'moss'}), frozenset({'地球'}), 0.75), (frozenset({'基'}), frozenset({'锤'}), 1.0), (frozenset({'锤'}), frozenset({'基'}), 1.0), (frozenset({'杰克'}), frozenset({'角色'}), 1.0)]
# 用户5563654349
# 关联规则：
# [(frozenset({'pang'}), frozenset({'唐人街'}), 0.7857142857142857), (frozenset({'pang'}), frozenset({'陈展鹏'}), 1.0), (frozenset({'陈展鹏'}), frozenset({'pang'}), 0.8235294117647058), (frozenset({'唐人街'}), frozenset({'陈展鹏'}), 0.8235294117647058), (frozenset({'陈展鹏'}), frozenset({'唐人街'}), 0.8235294117647058), (frozenset({'陳展鵬'}), frozenset({'唐人街'}), 0.8), (frozenset({'官'}), frozenset({'屎'}), 1.0), (frozenset({'小狗'}), frozenset({'狗'}), 0.75), (frozenset({'日记'}), frozenset({'汪星'}), 1.0), (frozenset({'汪星'}), frozenset({'日记'}), 0.96), (frozenset({'星'}), frozenset({'時間'}), 0.75), (frozenset({'時間'}), frozenset({'陳展鵬'}), 0.8333333333333334), (frozenset({'pang'}), frozenset({'陈展鹏', '唐人街'}), 0.7857142857142857)]
# 用户6346581869
# 关联规则：
# [(frozenset({'钱'}), frozenset({'funko'}), 1.0), (frozenset({'turner'}), frozenset({'sophie'}), 1.0), (frozenset({'sophie'}), frozenset({'turner'}), 0.8333333333333334), (frozenset({'战警'}), frozenset({'凤凰'}), 0.75), (frozenset({'凤凰'}), frozenset({'战警'}), 1.0), (frozenset({'品牌'}), frozenset({'权力'}), 1.0), (frozenset({'品牌'}), frozenset({'游戏'}), 1.0), (frozenset({'游戏'}), frozenset({'权力'}), 1.0), (frozenset({'权力'}), frozenset({'游戏'}), 1.0), (frozenset({'钱'}), frozenset({'漫威'}), 1.0), (frozenset({'钱'}), frozenset({'funko', '漫威'}), 1.0), (frozenset({'品牌'}), frozenset({'权力', '游戏'}), 1.0)]
# 用户6592829896
# 关联规则：
# [(frozenset({'cut'}), frozenset({'粉丝'}), 0.8), (frozenset({'八队'}), frozenset({'开箱'}), 1.0), (frozenset({'北京'}), frozenset({'开箱'}), 1.0), (frozenset({'喜剧'}), frozenset({'张云雷'}), 0.7142857142857143), (frozenset({'大吉'}), frozenset({'开箱'}), 1.0), (frozenset({'开箱'}), frozenset({'大吉'}), 0.7391304347826086), (frozenset({'张云雷'}), frozenset({'小辫儿'}), 0.7906976744186046), (frozenset({'小辫儿'}), frozenset({'张云雷'}), 1.0), (frozenset({'虎鲸'}), frozenset({'小辫儿'}), 1.0), (frozenset({'杨九郎'}), frozenset({'张云雷'}), 0.8), (frozenset({'演员'}), frozenset({'张云雷'}), 0.7142857142857143), (frozenset({'虎鲸'}), frozenset({'张云雷'}), 1.0), (frozenset({'栾云平'}), frozenset({'德云社'}), 0.875), (frozenset({'能耐'}), frozenset({'杨九郎'}), 0.7142857142857143), (frozenset({'虎鲸'}), frozenset({'小辫儿', '张云雷'}), 1.0)]
# 用户5656522522
# 关联规则：
# [(frozenset({'二爷'}), frozenset({'张云雷'}), 0.9285714285714286), (frozenset({'人气'}), frozenset({'小辫儿'}), 1.0), (frozenset({'人气'}), frozenset({'张云雷'}), 1.0), (frozenset({'人气'}), frozenset({'榜'}), 1.0), (frozenset({'榜'}), frozenset({'人气'}), 0.8), (frozenset({'人气'}), frozenset({'男友'}), 1.0), (frozenset({'男友'}), frozenset({'人气'}), 1.0), (frozenset({'君安'}), frozenset({'张云雷'}), 0.9047619047619048), (frozenset({'哥哥'}), frozenset({'张云雷'}), 0.90625), (frozenset({'辫儿'}), frozenset({'哥哥'}), 0.9333333333333333), (frozenset({'哥哥'}), frozenset({'辫儿'}), 0.875), (frozenset({'喜剧'}), frozenset({'张云雷'}), 0.975), (frozenset({'杨九郎'}), frozenset({'喜剧'}), 0.75), (frozenset({'烧饼'}), frozenset({'喜剧'}), 0.7857142857142857), (frozenset({'群口'}), frozenset({'喜剧'}), 0.7857142857142857), (frozenset({'小辫儿'}), frozenset({'张云雷'}), 1.0), (frozenset({'榜'}), frozenset({'小辫儿'}), 1.0), (frozenset({'演员'}), frozenset({'小辫儿'}), 0.7222222222222222), (frozenset({'男友'}), frozenset({'小辫儿'}), 1.0), (frozenset({'英雄'}), frozenset({'小辫儿'}), 0.7333333333333333), (frozenset({'手术'}), frozenset({'张云雷'}), 0.896551724137931), (frozenset({'报平安'}), frozenset({'张云雷'}), 1.0), (frozenset({'杨九郎'}), frozenset({'张云雷'}), 1.0), (frozenset({'榜'}), frozenset({'张云雷'}), 1.0), (frozenset({'演员'}), frozenset({'张云雷'}), 1.0), (frozenset({'烧饼'}), frozenset({'张云雷'}), 1.0), (frozenset({'男友'}), frozenset({'张云雷'}), 1.0), (frozenset({'粉丝'}), frozenset({'张云雷'}), 1.0), (frozenset({'群口'}), frozenset({'张云雷'}), 1.0), (frozenset({'英雄'}), frozenset({'张云雷'}), 0.9333333333333333), (frozenset({'身体'}), frozenset({'张云雷'}), 1.0), (frozenset({'辫儿'}), frozenset({'张云雷'}), 0.9), (frozenset({'钢钉'}), frozenset({'张云雷'}), 0.8421052631578947), (frozenset({'报平安'}), frozenset({'手术'}), 0.72), (frozenset({'钢钉'}), frozenset({'手术'}), 0.8421052631578947), (frozenset({'钢钉'}), frozenset({'报平安'}), 0.8421052631578947), (frozenset({'杨九郎'}), frozenset({'烧饼'}), 0.875), (frozenset({'烧饼'}), frozenset({'杨九郎'}), 1.0), (frozenset({'杨九郎'}), frozenset({'群口'}), 0.875), (frozenset({'群口'}), frozenset({'杨九郎'}), 1.0), (frozenset({'男友'}), frozenset({'榜'}), 1.0), (frozenset({'榜'}), frozenset({'男友'}), 0.8), (frozenset({'群口'}), frozenset({'烧饼'}), 1.0), (frozenset({'烧饼'}), frozenset({'群口'}), 1.0), (frozenset({'人气'}), frozenset({'小辫儿', '张云雷'}), 1.0), (frozenset({'人气'}), frozenset({'小辫儿', '榜'}), 1.0), (frozenset({'榜'}), frozenset({'小辫儿', '人气'}), 0.8), (frozenset({'人气'}), frozenset({'小辫儿', '男友'}), 1.0), (frozenset({'男友'}), frozenset({'小辫儿', '人气'}), 1.0), (frozenset({'人气'}), frozenset({'张云雷', '男友'}), 1.0), (frozenset({'男友'}), frozenset({'张云雷', '人气'}), 1.0), (frozenset({'人气'}), frozenset({'榜', '张云雷'}), 1.0), (frozenset({'榜'}), frozenset({'张云雷', '人气'}), 0.8), (frozenset({'人气'}), frozenset({'榜', '男友'}), 1.0), (frozenset({'榜'}), frozenset({'人气', '男友'}), 0.8), (frozenset({'男友'}), frozenset({'榜', '人气'}), 1.0), (frozenset({'辫儿'}), frozenset({'哥哥', '张云雷'}), 0.8333333333333334), (frozenset({'哥哥'}), frozenset({'张云雷', '辫儿'}), 0.78125), (frozenset({'杨九郎'}), frozenset({'喜剧', '张云雷'}), 0.75), (frozenset({'群口'}), frozenset({'喜剧', '张云雷'}), 0.7857142857142857), (frozenset({'群口'}), frozenset({'喜剧', '杨九郎'}), 0.7857142857142857), (frozenset({'烧饼'}), frozenset({'喜剧', '张云雷'}), 0.7857142857142857), (frozenset({'烧饼'}), frozenset({'喜剧', '杨九郎'}), 0.7857142857142857), (frozenset({'群口'}), frozenset({'烧饼', '喜剧'}), 0.7857142857142857), (frozenset({'烧饼'}), frozenset({'喜剧', '群口'}), 0.7857142857142857), (frozenset({'榜'}), frozenset({'小辫儿', '张云雷'}), 1.0), (frozenset({'演员'}), frozenset({'小辫儿', '张云雷'}), 0.7222222222222222), (frozenset({'男友'}), frozenset({'小辫儿', '张云雷'}), 1.0), (frozenset({'英雄'}), frozenset({'小辫儿', '张云雷'}), 0.7333333333333333), (frozenset({'男友'}), frozenset({'小辫儿', '榜'}), 1.0), (frozenset({'榜'}), frozenset({'小辫儿', '男友'}), 0.8), (frozenset({'报平安'}), frozenset({'手术', '张云雷'}), 0.72), (frozenset({'男友'}), frozenset({'榜', '张云雷'}), 1.0), (frozenset({'榜'}), frozenset({'张云雷', '男友'}), 0.8), (frozenset({'杨九郎'}), frozenset({'烧饼', '张云雷'}), 0.875), (frozenset({'烧饼'}), frozenset({'张云雷', '杨九郎'}), 1.0), ...
# 用户6517144122
# 关联规则：
# [(frozenset({'兴兴'}), frozenset({'张艺兴'}), 0.8181818181818182), (frozenset({'北极熊'}), frozenset({'垃圾'}), 1.0), (frozenset({'垃圾'}), frozenset({'贝壳'}), 0.7272727272727273), (frozenset({'时间'}), frozenset({'张艺兴'}), 0.75), (frozenset({'格莱美'}), frozenset({'张艺兴'}), 1.0), (frozenset({'梦'}), frozenset({'张艺兴'}), 0.9629629629629629), (frozenset({'电音'}), frozenset({'张艺兴'}), 0.8333333333333334), (frozenset({'舞台'}), frozenset({'张艺兴'}), 0.7857142857142857), (frozenset({'艺兴'}), frozenset({'张艺兴'}), 0.95), (frozenset({'雨林'}), frozenset({'张艺兴'}), 1.0), (frozenset({'青春'}), frozenset({'张艺兴'}), 1.0), (frozenset({'音乐'}), frozenset({'张艺兴'}), 0.9444444444444444), (frozenset({'抽奖'}), frozenset({'情人节'}), 0.8695652173913043), (frozenset({'情人节'}), frozenset({'抽奖'}), 0.7407407407407407), (frozenset({'条'}), frozenset({'情人节'}), 0.9), (frozenset({'情人节'}), frozenset({'红包'}), 0.7777777777777778), (frozenset({'红包'}), frozenset({'情人节'}), 0.7777777777777778), (frozenset({'情人节'}), frozenset({'金'}), 0.7407407407407407), (frozenset({'金'}), frozenset({'情人节'}), 1.0), (frozenset({'飞'}), frozenset({'情人节'}), 0.9), (frozenset({'抽奖'}), frozenset({'条'}), 0.8260869565217391), (frozenset({'条'}), frozenset({'抽奖'}), 0.95), (frozenset({'抽奖'}), frozenset({'红包'}), 0.9565217391304348), (frozenset({'红包'}), frozenset({'抽奖'}), 0.8148148148148148), (frozenset({'抽奖'}), frozenset({'金'}), 0.8695652173913043), (frozenset({'金'}), frozenset({'抽奖'}), 1.0), (frozenset({'抽奖'}), frozenset({'飞'}), 0.8260869565217391), (frozenset({'飞'}), frozenset({'抽奖'}), 0.95), (frozenset({'条'}), frozenset({'红包'}), 0.95), (frozenset({'红包'}), frozenset({'条'}), 0.7037037037037037), (frozenset({'条'}), frozenset({'金'}), 0.9), (frozenset({'金'}), frozenset({'条'}), 0.9), (frozenset({'条'}), frozenset({'飞'}), 0.95), (frozenset({'飞'}), frozenset({'条'}), 0.95), (frozenset({'格莱美'}), frozenset({'音乐'}), 0.8), (frozenset({'梦'}), frozenset({'雨林'}), 0.9259259259259259), (frozenset({'雨林'}), frozenset({'梦'}), 1.0), (frozenset({'金'}), frozenset({'红包'}), 1.0), (frozenset({'红包'}), frozenset({'金'}), 0.7407407407407407), (frozenset({'飞'}), frozenset({'红包'}), 1.0), (frozenset({'红包'}), frozenset({'飞'}), 0.7407407407407407), (frozenset({'飞'}), frozenset({'金'}), 0.9), (frozenset({'金'}), frozenset({'飞'}), 0.9), (frozenset({'梦'}), frozenset({'雨林', '张艺兴'}), 0.9259259259259259), (frozenset({'雨林'}), frozenset({'张艺兴', '梦'}), 1.0), (frozenset({'格莱美'}), frozenset({'音乐', '张艺兴'}), 0.8), (frozenset({'条'}), frozenset({'情人节', '抽奖'}), 0.9), (frozenset({'抽奖'}), frozenset({'情人节', '条'}), 0.782608695652174), (frozenset({'抽奖'}), frozenset({'红包', '情人节'}), 0.8695652173913043), (frozenset({'情人节'}), frozenset({'红包', '抽奖'}), 0.7407407407407407), (frozenset({'红包'}), frozenset({'情人节', '抽奖'}), 0.7407407407407407), (frozenset({'条'}), frozenset({'红包', '情人节'}), 0.9), (frozenset({'情人节'}), frozenset({'红包', '金'}), 0.7407407407407407), (frozenset({'金'}), frozenset({'红包', '情人节'}), 1.0), (frozenset({'红包'}), frozenset({'金', '情人节'}), 0.7407407407407407), (frozenset({'飞'}), frozenset({'红包', '情人节'}), 0.9), (frozenset({'抽奖'}), frozenset({'金', '情人节'}), 0.8695652173913043), (frozenset({'情人节'}), frozenset({'金', '抽奖'}), 0.7407407407407407), (frozenset({'金'}), frozenset({'情人节', '抽奖'}), 1.0), (frozenset({'条'}), frozenset({'金', '情人节'}), 0.9), (frozenset({'金'}), frozenset({'情人节', '条'}), 0.9), (frozenset({'飞'}), frozenset({'金', '情人节'}), 0.9), (frozenset({'金'}), frozenset({'飞', '情人节'}), 0.9), (frozenset({'抽奖'}), frozenset({'飞', '情人节'}), 0.782608695652174), (frozenset({'飞'}), frozenset({'情人节', '抽奖'}), 0.9), (frozenset({'条'}), frozenset({'飞', '情人节'}), 0.9), (frozenset({'飞'}), frozenset({'情人节', '条'}), 0.9), (frozenset({'抽奖'}), frozenset({'红包', '条'}), 0.8260869565217391), (frozenset({'条'}), frozenset({'红包', '抽奖'}), 0.95), (frozenset({'红包'}), frozenset({'条', '抽奖'}), 0.7037037037037037), (frozenset({'抽奖'}), frozenset({'红包', '金'}), 0.8695652173913043), (frozenset({'金'}), frozenset({'红包', '抽奖'}), 1.0), (frozenset({'红包'}), frozenset({'金', '抽奖'}), 0.7407407407407407), (frozenset({'抽奖'}), frozenset({'红包' ...
# 用户5698255237
# 关联规则：
# [(frozenset({'上线'}), frozenset({'mv'}), 0.8695652173913043), (frozenset({'故事'}), frozenset({'mv'}), 1.0), (frozenset({'歌'}), frozenset({'mv'}), 0.7142857142857143), (frozenset({'王冠'}), frozenset({'mv'}), 0.9375), (frozenset({'画面'}), frozenset({'mv'}), 1.0), (frozenset({'mv'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'飞鸟'}), frozenset({'mv'}), 1.0), (frozenset({'上线'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'人物'}), frozenset({'环球'}), 1.0), (frozenset({'环球'}), frozenset({'人物'}), 1.0), (frozenset({'人物'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'公益'}), frozenset({'粉丝'}), 0.7333333333333333), (frozenset({'公益'}), frozenset({'能量'}), 0.8), (frozenset({'能量'}), frozenset({'公益'}), 0.8571428571428571), (frozenset({'公益'}), frozenset({'蔡徐坤'}), 0.9333333333333333), (frozenset({'投票'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'画面'}), frozenset({'故事'}), 0.8), (frozenset({'故事'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'数据'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'文艺'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'时间'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'榜'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'歌'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'王冠'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'飞鸟'}), frozenset({'王冠'}), 0.8333333333333334), (frozenset({'王冠'}), frozenset({'飞鸟'}), 0.9375), (frozenset({'环球'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'画面'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'能量'}), frozenset({'粉丝'}), 0.8571428571428571), (frozenset({'粉丝'}), frozenset({'能量'}), 0.7058823529411765), (frozenset({'粉丝'}), frozenset({'蔡徐坤'}), 0.9411764705882353), (frozenset({'能量'}), frozenset({'蔡徐坤'}), 0.9285714285714286), (frozenset({'蔡'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'音乐'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'飞鸟'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'上线'}), frozenset({'mv', '蔡徐坤'}), 0.8695652173913043), (frozenset({'故事'}), frozenset({'mv', '蔡徐坤'}), 1.0), (frozenset({'歌'}), frozenset({'mv', '蔡徐坤'}), 0.7142857142857143), (frozenset({'王冠'}), frozenset({'mv', '蔡徐坤'}), 0.9375), (frozenset({'飞鸟'}), frozenset({'王冠', 'mv'}), 0.8333333333333334), (frozenset({'王冠'}), frozenset({'mv', '飞鸟'}), 0.9375), (frozenset({'画面'}), frozenset({'mv', '故事'}), 0.8), (frozenset({'画面'}), frozenset({'mv', '蔡徐坤'}), 1.0), (frozenset({'飞鸟'}), frozenset({'mv', '蔡徐坤'}), 1.0), (frozenset({'人物'}), frozenset({'蔡徐坤', '环球'}), 1.0), (frozenset({'环球'}), frozenset({'蔡徐坤', '人物'}), 1.0), (frozenset({'公益'}), frozenset({'粉丝', '能量'}), 0.7333333333333333), (frozenset({'能量'}), frozenset({'粉丝', '公益'}), 0.7857142857142857), (frozenset({'公益'}), frozenset({'能量', '蔡徐坤'}), 0.7333333333333333), (frozenset({'能量'}), frozenset({'公益', '蔡徐坤'}), 0.7857142857142857), (frozenset({'画面'}), frozenset({'故事', '蔡徐坤'}), 0.8), (frozenset({'飞鸟'}), frozenset({'王冠', '蔡徐坤'}), 0.8333333333333334), (frozenset({'王冠'}), frozenset({'飞鸟', '蔡徐坤'}), 0.9375), (frozenset({'能量'}), frozenset({'粉丝', '蔡徐坤'}), 0.7857142857142857)]
# 用户3777522447
# 关联规则：
# [(frozenset({'ggad'}), frozenset({'德沃'}), 0.8333333333333334), (frozenset({'ggad'}), frozenset({'格林'}), 0.8333333333333334), (frozenset({'同性'}), frozenset({'中国'}), 1.0), (frozenset({'张'}), frozenset({'亚太区'}), 1.0), (frozenset({'亚太区'}), frozenset({'张'}), 1.0), (frozenset({'日本'}), frozenset({'亚太区'}), 0.8823529411764706), (frozenset({'亚太区'}), frozenset({'日本'}), 0.8823529411764706), (frozenset({'面孔'}), frozenset({'亚太区'}), 1.0), (frozenset({'亚太区'}), frozenset({'面孔'}), 1.0), (frozenset({'德普'}), frozenset({'动物'}), 0.75), (frozenset({'动物'}), frozenset({'德沃'}), 0.7894736842105263), (frozenset({'德沃'}), frozenset({'动物'}), 0.8333333333333334), (frozenset({'动物'}), frozenset({'格林'}), 0.7894736842105263), (frozenset({'格林'}), frozenset({'动物'}), 0.8333333333333334), (frozenset({'罪'}), frozenset({'动物'}), 0.9230769230769231), (frozenset({'哈利'}), frozenset({'波特'}), 0.9230769230769231), (frozenset({'波特'}), frozenset({'哈利'}), 0.8), (frozenset({'邓'}), frozenset({'布利'}), 1.0), (frozenset({'布利'}), frozenset({'邓'}), 1.0), (frozenset({'日本'}), frozenset({'张'}), 0.8823529411764706), (frozenset({'张'}), frozenset({'日本'}), 0.8823529411764706), (frozenset({'张'}), frozenset({'面孔'}), 1.0), (frozenset({'面孔'}), frozenset({'张'}), 1.0), (frozenset({'德普'}), frozenset({'德沃'}), 1.0), (frozenset({'德普'}), frozenset({'格林'}), 1.0), (frozenset({'德普'}), frozenset({'罪'}), 0.75), (frozenset({'德沃'}), frozenset({'格林'}), 1.0), (frozenset({'格林'}), frozenset({'德沃'}), 1.0), (frozenset({'罪'}), frozenset({'德沃'}), 0.9230769230769231), (frozenset({'日本'}), frozenset({'面孔'}), 0.8823529411764706), (frozenset({'面孔'}), frozenset({'日本'}), 0.8823529411764706), (frozenset({'罪'}), frozenset({'格林'}), 0.9230769230769231), (frozenset({'ggad'}), frozenset({'格林', '德沃'}), 0.8333333333333334), (frozenset({'日本'}), frozenset({'亚太区', '张'}), 0.8823529411764706), (frozenset({'张'}), frozenset({'亚太区', '日本'}), 0.8823529411764706), (frozenset({'亚太区'}), frozenset({'张', '日本'}), 0.8823529411764706), (frozenset({'面孔'}), frozenset({'亚太区', '张'}), 1.0), (frozenset({'张'}), frozenset({'亚太区', '面孔'}), 1.0), (frozenset({'亚太区'}), frozenset({'面孔', '张'}), 1.0), (frozenset({'面孔'}), frozenset({'亚太区', '日本'}), 0.8823529411764706), (frozenset({'日本'}), frozenset({'亚太区', '面孔'}), 0.8823529411764706), (frozenset({'亚太区'}), frozenset({'面孔', '日本'}), 0.8823529411764706), (frozenset({'德普'}), frozenset({'德沃', '动物'}), 0.75), (frozenset({'德普'}), frozenset({'罪', '动物'}), 0.75), (frozenset({'德普'}), frozenset({'格林', '动物'}), 0.75), (frozenset({'动物'}), frozenset({'格林', '德沃'}), 0.7894736842105263), (frozenset({'德沃'}), frozenset({'格林', '动物'}), 0.8333333333333334), (frozenset({'格林'}), frozenset({'德沃', '动物'}), 0.8333333333333334), (frozenset({'罪'}), frozenset({'格林', '动物'}), 0.9230769230769231), (frozenset({'罪'}), frozenset({'德沃', '动物'}), 0.9230769230769231), (frozenset({'日本'}), frozenset({'面孔', '张'}), 0.8823529411764706), (frozenset({'张'}), frozenset({'面孔', '日本'}), 0.8823529411764706), (frozenset({'面孔'}), frozenset({'张', '日本'}), 0.8823529411764706), (frozenset({'德普'}), frozenset({'罪', '德沃'}), 0.75), (frozenset({'德普'}), frozenset({'格林', '德沃'}), 1.0), (frozenset({'德普'}), frozenset({'格林', '罪'}), 0.75), (frozenset({'罪'}), frozenset({'格林', '德沃'}), 0.9230769230769231)]
# 用户2382872823
# 关联规则：
# [(frozenset({'pinterest'}), frozenset({'全民'}), 1.0), (frozenset({'pinterest'}), frozenset({'哲人'}), 1.0), (frozenset({'图源'}), frozenset({'pinterest'}), 0.9375), (frozenset({'pinterest'}), frozenset({'图源'}), 1.0), (frozenset({'pinterest'}), frozenset({'宝季'}), 1.0), (frozenset({'pinterest'}), frozenset({'珠宝'}), 1.0), (frozenset({'祖母绿'}), frozenset({'pinterest'}), 1.0), (frozenset({'pinterest'}), frozenset({'艺术'}), 1.0), (frozenset({'首饰'}), frozenset({'pinterest'}), 0.75), (frozenset({'全民'}), frozenset({'哲人'}), 1.0), (frozenset({'哲人'}), frozenset({'全民'}), 0.9555555555555556), (frozenset({'全民'}), frozenset({'图源'}), 0.7441860465116279), (frozenset({'图源'}), frozenset({'全民'}), 1.0), (frozenset({'宝季'}), frozenset({'全民'}), 1.0), (frozenset({'全民'}), frozenset({'宝季'}), 1.0), (frozenset({'全民'}), frozenset({'珠宝'}), 0.9534883720930233), (frozenset({'珠宝'}), frozenset({'全民'}), 0.9534883720930233), (frozenset({'祖母绿'}), frozenset({'全民'}), 1.0), (frozenset({'全民'}), frozenset({'艺术'}), 1.0), (frozenset({'艺术'}), frozenset({'全民'}), 0.9555555555555556), (frozenset({'首饰'}), frozenset({'全民'}), 1.0), (frozenset({'哈利'}), frozenset({'波特'}), 1.0), (frozenset({'波特'}), frozenset({'哈利'}), 1.0), (frozenset({'图源'}), frozenset({'哲人'}), 1.0), (frozenset({'哲人'}), frozenset({'图源'}), 0.7111111111111111), (frozenset({'宝季'}), frozenset({'哲人'}), 1.0), (frozenset({'哲人'}), frozenset({'宝季'}), 0.9555555555555556), (frozenset({'情人节'}), frozenset({'哲人'}), 1.0), (frozenset({'珠宝'}), frozenset({'哲人'}), 1.0), (frozenset({'哲人'}), frozenset({'珠宝'}), 0.9555555555555556), (frozenset({'祖母绿'}), frozenset({'哲人'}), 1.0), (frozenset({'哲人'}), frozenset({'艺术'}), 1.0), (frozenset({'艺术'}), frozenset({'哲人'}), 1.0), (frozenset({'首饰'}), frozenset({'哲人'}), 1.0), (frozenset({'宝季'}), frozenset({'图源'}), 0.7441860465116279), (frozenset({'图源'}), frozenset({'宝季'}), 1.0), (frozenset({'图源'}), frozenset({'珠宝'}), 1.0), (frozenset({'珠宝'}), frozenset({'图源'}), 0.7441860465116279), (frozenset({'祖母绿'}), frozenset({'图源'}), 1.0), (frozenset({'图源'}), frozenset({'艺术'}), 1.0), (frozenset({'艺术'}), frozenset({'图源'}), 0.7111111111111111), (frozenset({'首饰'}), frozenset({'图源'}), 0.75), (frozenset({'宝季'}), frozenset({'珠宝'}), 0.9534883720930233), (frozenset({'珠宝'}), frozenset({'宝季'}), 0.9534883720930233), (frozenset({'祖母绿'}), frozenset({'宝季'}), 1.0), (frozenset({'宝季'}), frozenset({'艺术'}), 1.0), (frozenset({'艺术'}), frozenset({'宝季'}), 0.9555555555555556), (frozenset({'首饰'}), frozenset({'宝季'}), 1.0), (frozenset({'情人节'}), frozenset({'艺术'}), 1.0), (frozenset({'祖母绿'}), frozenset({'珠宝'}), 1.0), (frozenset({'珠宝'}), frozenset({'艺术'}), 1.0), (frozenset({'艺术'}), frozenset({'珠宝'}), 0.9555555555555556), (frozenset({'首饰'}), frozenset({'珠宝'}), 1.0), (frozenset({'祖母绿'}), frozenset({'艺术'}), 1.0), (frozenset({'首饰'}), frozenset({'艺术'}), 1.0), (frozenset({'pinterest'}), frozenset({'哲人', '全民'}), 1.0), (frozenset({'图源'}), frozenset({'pinterest', '全民'}), 0.9375), (frozenset({'pinterest'}), frozenset({'全民', '图源'}), 1.0), (frozenset({'pinterest'}), frozenset({'全民', '宝季'}), 1.0), (frozenset({'pinterest'}), frozenset({'全民', '珠宝'}), 1.0), (frozenset({'祖母绿'}), frozenset({'pinterest', '全民'}), 1.0), (frozenset({'pinterest'}), frozenset({'艺术', '全民'}), 1.0), (frozenset({'首饰'}), frozenset({'pinterest', '全民'}), 0.75), (frozenset({'图源'}), frozenset({'pinterest', '哲人'}), 0.9375), (frozenset({'pinterest'}), frozenset({'哲人', '图源'}), 1.0), (frozenset({'pinterest'}), frozenset({'哲人', '宝季'}), 1.0), (frozenset({'pinterest'}), frozenset({'哲人', '珠宝'}), 1.0), (frozenset({'祖母绿'}), frozenset({'pinterest', '哲人'}), 1.0), (frozenset({'pinterest'}), frozenset({'艺术', '哲人'}), 1.0), (frozenset({'首饰'}), frozenset({'pinterest', '哲人'}), 0.75), (frozenset({'图源'}), frozenset({'pinterest', '宝季'}), 0.9375), (frozenset({'pinterest'}), frozenset({'图源', '宝季'}), 1.0), (frozenset({'图源'}), frozenset({'pinterest', '珠宝'}), 0.9375), (frozenset({'pinterest'}), frozenset({'图源', '珠宝'}), 1.0), (frozenset({'祖母绿'}), frozenset({'pinterest', '图源'}), 1.0), (frozenset({'图源'}), frozenset({'pinterest', ' ...
# 用户6231411661
# 关联规则：
# [(frozenset({'hannah'}), frozenset({'昆凌'}), 0.8571428571428571), (frozenset({'专辑'}), frozenset({'周杰伦'}), 0.75), (frozenset({'电影'}), frozenset({'功夫'}), 1.0), (frozenset({'味'}), frozenset({'周杰伦'}), 1.0), (frozenset({'情人节'}), frozenset({'周杰伦'}), 0.75), (frozenset({'拉斯维加斯'}), frozenset({'周杰伦'}), 0.9), (frozenset({'杰伦'}), frozenset({'周杰伦'}), 0.875), (frozenset({'杰倫'}), frozenset({'周杰伦'}), 1.0), (frozenset({'演唱会'}), frozenset({'周杰伦'}), 0.9166666666666666), (frozenset({'粉丝'}), frozenset({'周杰伦'}), 0.75), (frozenset({'美国'}), frozenset({'周杰伦'}), 0.8333333333333334), (frozenset({'拉斯维加斯'}), frozenset({'演唱会'}), 0.8), (frozenset({'美国'}), frozenset({'拉斯维加斯'}), 0.8333333333333334), (frozenset({'美国'}), frozenset({'演唱会'}), 0.8333333333333334), (frozenset({'赫'}), frozenset({'老板'}), 0.7142857142857143), (frozenset({'老板'}), frozenset({'陈赫'}), 1.0), (frozenset({'老板'}), frozenset({'陪伴'}), 1.0), (frozenset({'赫'}), frozenset({'陈赫'}), 1.0), (frozenset({'赫'}), frozenset({'陪伴'}), 1.0), (frozenset({'陈赫'}), frozenset({'陪伴'}), 0.9411764705882353), (frozenset({'陪伴'}), frozenset({'陈赫'}), 1.0), (frozenset({'拉斯维加斯'}), frozenset({'演唱会', '周杰伦'}), 0.7), (frozenset({'美国'}), frozenset({'演唱会', '拉斯维加斯'}), 0.8333333333333334), (frozenset({'赫'}), frozenset({'老板', '陈赫'}), 0.7142857142857143), (frozenset({'赫'}), frozenset({'老板', '陪伴'}), 0.7142857142857143), (frozenset({'老板'}), frozenset({'陪伴', '陈赫'}), 1.0), (frozenset({'赫'}), frozenset({'陪伴', '陈赫'}), 1.0)]
# 用户5983422961
# 关联规则：
# [(frozenset({'同学'}), frozenset({'红包'}), 0.8), (frozenset({'夫夫'}), frozenset({'坛'}), 1.0), (frozenset({'坛'}), frozenset({'幕星'}), 0.75), (frozenset({'幕星'}), frozenset({'坛'}), 1.0), (frozenset({'风'}), frozenset({'大陆'}), 1.0), (frozenset({'大陆'}), frozenset({'风'}), 1.0), (frozenset({'夫夫'}), frozenset({'幕星'}), 1.0), (frozenset({'现金'}), frozenset({'红包'}), 0.8333333333333334), (frozenset({'夫夫'}), frozenset({'幕星', '坛'}), 1.0)]
# 用户5943928997
# 关联规则：
# [(frozenset({'ud'}), frozenset({'品牌'}), 1.0), (frozenset({'品牌'}), frozenset({'ud'}), 1.0), (frozenset({'ud'}), frozenset({'小辫儿'}), 0.7), (frozenset({'ud'}), frozenset({'张云雷'}), 1.0), (frozenset({'挚友'}), frozenset({'ud'}), 1.0), (frozenset({'ud'}), frozenset({'挚友'}), 1.0), (frozenset({'ud'}), frozenset({'时尚'}), 0.8), (frozenset({'时尚'}), frozenset({'ud'}), 1.0), (frozenset({'周九良'}), frozenset({'孟鹤堂'}), 0.8695652173913043), (frozenset({'新人'}), frozenset({'周九良'}), 0.8888888888888888), (frozenset({'品牌'}), frozenset({'小辫儿'}), 0.7), (frozenset({'品牌'}), frozenset({'张云雷'}), 1.0), (frozenset({'挚友'}), frozenset({'品牌'}), 1.0), (frozenset({'品牌'}), frozenset({'挚友'}), 1.0), (frozenset({'时尚'}), frozenset({'品牌'}), 1.0), (frozenset({'品牌'}), frozenset({'时尚'}), 0.8), (frozenset({'喜剧'}), frozenset({'张云雷'}), 0.8461538461538461), (frozenset({'新人'}), frozenset({'孟鹤堂'}), 0.8888888888888888), (frozenset({'小羊'}), frozenset({'杨九郎'}), 1.0), (frozenset({'小辫儿'}), frozenset({'张云雷'}), 1.0), (frozenset({'挚友'}), frozenset({'小辫儿'}), 0.7), (frozenset({'情景喜剧'}), frozenset({'张云雷'}), 0.75), (frozenset({'挚友'}), frozenset({'张云雷'}), 1.0), (frozenset({'时尚'}), frozenset({'张云雷'}), 1.0), (frozenset({'杨九郎'}), frozenset({'张云雷'}), 0.725), (frozenset({'演员'}), frozenset({'张云雷'}), 0.7142857142857143), (frozenset({'德云社'}), frozenset({'演员'}), 0.7368421052631579), (frozenset({'演员'}), frozenset({'德云社'}), 1.0), (frozenset({'情景喜剧'}), frozenset({'杨九郎'}), 0.8), (frozenset({'情景喜剧'}), frozenset({'能耐'}), 1.0), (frozenset({'指路'}), frozenset({'能耐'}), 0.75), (frozenset({'挚友'}), frozenset({'时尚'}), 0.8), (frozenset({'时尚'}), frozenset({'挚友'}), 1.0), (frozenset({'演员'}), frozenset({'杨九郎'}), 0.7857142857142857), (frozenset({'ud'}), frozenset({'品牌', '小辫儿'}), 0.7), (frozenset({'品牌'}), frozenset({'小辫儿', 'ud'}), 0.7), (frozenset({'ud'}), frozenset({'品牌', '张云雷'}), 1.0), (frozenset({'品牌'}), frozenset({'ud', '张云雷'}), 1.0), (frozenset({'挚友'}), frozenset({'品牌', 'ud'}), 1.0), (frozenset({'ud'}), frozenset({'品牌', '挚友'}), 1.0), (frozenset({'品牌'}), frozenset({'ud', '挚友'}), 1.0), (frozenset({'ud'}), frozenset({'品牌', '时尚'}), 0.8), (frozenset({'时尚'}), frozenset({'品牌', 'ud'}), 1.0), (frozenset({'品牌'}), frozenset({'ud', '时尚'}), 0.8), (frozenset({'ud'}), frozenset({'小辫儿', '张云雷'}), 0.7), (frozenset({'挚友'}), frozenset({'小辫儿', 'ud'}), 0.7), (frozenset({'ud'}), frozenset({'小辫儿', '挚友'}), 0.7), (frozenset({'挚友'}), frozenset({'ud', '张云雷'}), 1.0), (frozenset({'ud'}), frozenset({'张云雷', '挚友'}), 1.0), (frozenset({'ud'}), frozenset({'时尚', '张云雷'}), 0.8), (frozenset({'时尚'}), frozenset({'ud', '张云雷'}), 1.0), (frozenset({'挚友'}), frozenset({'ud', '时尚'}), 0.8), (frozenset({'ud'}), frozenset({'时尚', '挚友'}), 0.8), (frozenset({'时尚'}), frozenset({'ud', '挚友'}), 1.0), (frozenset({'新人'}), frozenset({'周九良', '孟鹤堂'}), 0.7777777777777778), (frozenset({'品牌'}), frozenset({'小辫儿', '张云雷'}), 0.7), (frozenset({'挚友'}), frozenset({'品牌', '小辫儿'}), 0.7), (frozenset({'品牌'}), frozenset({'小辫儿', '挚友'}), 0.7), (frozenset({'挚友'}), frozenset({'品牌', '张云雷'}), 1.0), (frozenset({'品牌'}), frozenset({'张云雷', '挚友'}), 1.0), (frozenset({'时尚'}), frozenset({'品牌', '张云雷'}), 1.0), (frozenset({'品牌'}), frozenset({'张云雷', '时尚'}), 0.8), (frozenset({'挚友'}), frozenset({'品牌', '时尚'}), 0.8), (frozenset({'时尚'}), frozenset({'品牌', '挚友'}), 1.0), (frozenset({'品牌'}), frozenset({'时尚', '挚友'}), 0.8), (frozenset({'挚友'}), frozenset({'小辫儿', '张云雷'}), 0.7), (frozenset({'情景喜剧'}), frozenset({'张云雷', '杨九郎'}), 0.75), (frozenset({'情景喜剧'}), frozenset({'张云雷', '能耐'}), 0.75), (frozenset({'挚友'}), frozenset({'张云雷', '时尚'}), 0.8), (frozenset({'时尚'}), frozenset({'张云雷', '挚友'}), 1.0), (frozenset({'演员'}), frozenset({'德云社', '张云雷'}), 0.7142857142857143), (frozenset({'演员'}), frozenset({'张云雷', '杨九郎'}), 0.7142857142857143), (frozenset({'演员'}), frozenset({'德云社', '杨九郎'}), 0.7857142857142857), (frozenset({'情景喜剧'}), frozenset({'杨九郎', '能耐'}), 0.8)]
# 用户5073092199
# 关联规则：
# [(frozenset({'white'}), frozenset({'白宇'}), 1.0), (frozenset({'个性'}), frozenset({'白宇'}), 1.0), (frozenset({'皮肤'}), frozenset({'个性'}), 1.0), (frozenset({'个性'}), frozenset({'皮肤'}), 1.0), (frozenset({'魂'}), frozenset({'剧版镇'}), 0.8333333333333334), (frozenset({'剧版镇'}), frozenset({'魂'}), 1.0), (frozenset({'哥哥'}), frozenset({'白宇'}), 0.7142857142857143), (frozenset({'情人节'}), frozenset({'白宇'}), 0.7777777777777778), (frozenset({'星'}), frozenset({'白宇'}), 0.75), (frozenset({'星'}), frozenset({'锋味'}), 0.75), (frozenset({'锋味'}), frozenset({'星'}), 1.0), (frozenset({'朱一龙'}), frozenset({'白宇'}), 1.0), (frozenset({'沈巍'}), frozenset({'澜'}), 0.75), (frozenset({'皮肤'}), frozenset({'白宇'}), 1.0), (frozenset({'皮肤'}), frozenset({'个性', '白宇'}), 1.0), (frozenset({'个性'}), frozenset({'皮肤', '白宇'}), 1.0)]
# 用户5102304530
# 关联规则：
# [(frozenset({'ai'}), frozenset({'moss'}), 0.7777777777777778), (frozenset({'ai'}), frozenset({'地球'}), 0.7777777777777778), (frozenset({'ai'}), frozenset({'流浪'}), 0.7777777777777778), (frozenset({'cp'}), frozenset({'moss'}), 1.0), (frozenset({'刘培强'}), frozenset({'moss'}), 1.0), (frozenset({'贾尼'}), frozenset({'moss'}), 0.8), (frozenset({'tony'}), frozenset({'贾'}), 1.0), (frozenset({'刘培强'}), frozenset({'地球'}), 0.7142857142857143), (frozenset({'刘培强'}), frozenset({'流浪'}), 0.7142857142857143), (frozenset({'刘培强'}), frozenset({'贾尼'}), 0.7142857142857143), (frozenset({'地球'}), frozenset({'流浪'}), 0.85), (frozenset({'流浪'}), frozenset({'地球'}), 0.9444444444444444), (frozenset({'女子'}), frozenset({'赵宇'}), 1.0), (frozenset({'ai'}), frozenset({'流浪', '地球'}), 0.7777777777777778), (frozenset({'刘培强'}), frozenset({'moss', '地球'}), 0.7142857142857143), (frozenset({'刘培强'}), frozenset({'moss', '流浪'}), 0.7142857142857143), (frozenset({'刘培强'}), frozenset({'moss', '贾尼'}), 0.7142857142857143), (frozenset({'刘培强'}), frozenset({'流浪', '地球'}), 0.7142857142857143)]
# 用户5895030162
# 关联规则：
# [(frozenset({'布利'}), frozenset({'德沃'}), 0.8571428571428571), (frozenset({'布利'}), frozenset({'格林'}), 0.8571428571428571), (frozenset({'布利'}), frozenset({'纽特'}), 0.7142857142857143), (frozenset({'纽特'}), frozenset({'布利'}), 1.0), (frozenset({'邓'}), frozenset({'布利'}), 0.7777777777777778), (frozenset({'布利'}), frozenset({'邓'}), 1.0), (frozenset({'德沃'}), frozenset({'格林'}), 1.0), (frozenset({'格林'}), frozenset({'德沃'}), 1.0), (frozenset({'纽特'}), frozenset({'德沃'}), 1.0), (frozenset({'邓'}), frozenset({'德沃'}), 0.7777777777777778), (frozenset({'纽特'}), frozenset({'格林'}), 1.0), (frozenset({'邓'}), frozenset({'格林'}), 0.7777777777777778), (frozenset({'纽特'}), frozenset({'邓'}), 1.0), (frozenset({'布利'}), frozenset({'德沃', '邓'}), 0.8571428571428571), (frozenset({'布利'}), frozenset({'格林', '德沃'}), 0.8571428571428571), (frozenset({'纽特'}), frozenset({'格林', '布利'}), 1.0), (frozenset({'布利'}), frozenset({'格林', '纽特'}), 0.7142857142857143), (frozenset({'布利'}), frozenset({'格林', '邓'}), 0.8571428571428571), (frozenset({'布利'}), frozenset({'纽特', '德沃'}), 0.7142857142857143), (frozenset({'纽特'}), frozenset({'布利', '德沃'}), 1.0), (frozenset({'布利'}), frozenset({'纽特', '邓'}), 0.7142857142857143), (frozenset({'纽特'}), frozenset({'布利', '邓'}), 1.0), (frozenset({'纽特'}), frozenset({'格林', '德沃'}), 1.0), (frozenset({'邓'}), frozenset({'格林', '德沃'}), 0.7777777777777778), (frozenset({'纽特'}), frozenset({'德沃', '邓'}), 1.0), (frozenset({'纽特'}), frozenset({'格林', '邓'}), 1.0)]
# 用户1900760151
# 关联规则：
# [(frozenset({'专场'}), frozenset({'事'}), 0.75), (frozenset({'声入'}), frozenset({'人心'}), 1.0), (frozenset({'人心'}), frozenset({'声入'}), 1.0), (frozenset({'孟鹤堂'}), frozenset({'周九良'}), 1.0), (frozenset({'周九良'}), frozenset({'孟鹤堂'}), 1.0), (frozenset({'李'}), frozenset({'演员'}), 1.0)]
# 用户5676193931
# 关联规则：
# [(frozenset({'cxk'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'ikun'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'大会'}), frozenset({'oppo'}), 1.0), (frozenset({'oppo'}), frozenset({'大会'}), 1.0), (frozenset({'上线'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'舞台'}), frozenset({'作品'}), 0.8333333333333334), (frozenset({'作品'}), frozenset({'蔡徐坤'}), 0.7272727272727273), (frozenset({'徐'}), frozenset({'坤'}), 1.0), (frozenset({'坤'}), frozenset({'徐'}), 1.0), (frozenset({'蔡'}), frozenset({'坤'}), 0.7777777777777778), (frozenset({'坤'}), frozenset({'蔡'}), 1.0), (frozenset({'坤'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'小米'}), frozenset({'手机'}), 1.0), (frozenset({'蔡'}), frozenset({'徐'}), 0.7777777777777778), (frozenset({'徐'}), frozenset({'蔡'}), 1.0), (frozenset({'徐'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'数据'}), frozenset({'粉丝'}), 1.0), (frozenset({'数据'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'明星'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'榜'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'粉丝'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'舞台'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'蔡'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'音乐'}), frozenset({'蔡徐坤'}), 1.0), (frozenset({'舞台'}), frozenset({'作品', '蔡徐坤'}), 0.8333333333333334), (frozenset({'徐'}), frozenset({'坤', '蔡'}), 1.0), (frozenset({'蔡'}), frozenset({'坤', '徐'}), 0.7777777777777778), (frozenset({'坤'}), frozenset({'徐', '蔡'}), 1.0), (frozenset({'徐'}), frozenset({'坤', '蔡徐坤'}), 1.0), (frozenset({'坤'}), frozenset({'徐', '蔡徐坤'}), 1.0), (frozenset({'蔡'}), frozenset({'坤', '蔡徐坤'}), 0.7777777777777778), (frozenset({'坤'}), frozenset({'蔡', '蔡徐坤'}), 1.0), (frozenset({'蔡'}), frozenset({'徐', '蔡徐坤'}), 0.7777777777777778), (frozenset({'徐'}), frozenset({'蔡', '蔡徐坤'}), 1.0), (frozenset({'数据'}), frozenset({'粉丝', '蔡徐坤'}), 1.0)]
# 用户6615903598
# 关联规则：
# [(frozenset({'ssr'}), frozenset({'手游'}), 1.0), (frozenset({'ssr'}), frozenset({'阴阳师'}), 1.0), (frozenset({'剧情'}), frozenset({'万花筒'}), 1.0), (frozenset({'岐'}), frozenset({'蛇'}), 1.0), (frozenset({'蛇'}), frozenset({'岐'}), 0.8571428571428571), (frozenset({'岐'}), frozenset({'阴阳师'}), 1.0), (frozenset({'沙雕'}), frozenset({'情人节'}), 1.0), (frozenset({'手游'}), frozenset({'阴阳师'}), 0.9), (frozenset({'祖师'}), frozenset({'魔'}), 1.0), (frozenset({'魔'}), frozenset({'祖师'}), 0.75), (frozenset({'蛇'}), frozenset({'阴阳师'}), 1.0), (frozenset({'ssr'}), frozenset({'阴阳师', '手游'}), 1.0), (frozenset({'岐'}), frozenset({'蛇', '阴阳师'}), 1.0), (frozenset({'蛇'}), frozenset({'岐', '阴阳师'}), 0.8571428571428571)]
# 用户6440930115
# 关联规则：
# [(frozenset({'ggad'}), frozenset({'动物'}), 0.75), (frozenset({'罪'}), frozenset({'动物'}), 0.8333333333333334), (frozenset({'布利'}), frozenset({'德沃'}), 0.7142857142857143), (frozenset({'布利'}), frozenset({'格林'}), 0.7142857142857143), (frozenset({'邓'}), frozenset({'布利'}), 1.0), (frozenset({'布利'}), frozenset({'邓'}), 1.0), (frozenset({'德沃'}), frozenset({'格林'}), 1.0), (frozenset({'格林'}), frozenset({'德沃'}), 1.0), (frozenset({'罪'}), frozenset({'德沃'}), 0.8333333333333334), (frozenset({'邓'}), frozenset({'德沃'}), 0.7142857142857143), (frozenset({'罪'}), frozenset({'格林'}), 0.8333333333333334), (frozenset({'邓'}), frozenset({'格林'}), 0.7142857142857143), (frozenset({'粉丝'}), frozenset({'漫威'}), 0.75), (frozenset({'罪'}), frozenset({'格林', '动物'}), 0.8333333333333334), (frozenset({'罪'}), frozenset({'德沃', '动物'}), 0.8333333333333334), (frozenset({'邓'}), frozenset({'布利', '德沃'}), 0.7142857142857143), (frozenset({'布利'}), frozenset({'德沃', '邓'}), 0.7142857142857143), (frozenset({'布利'}), frozenset({'格林', '德沃'}), 0.7142857142857143), (frozenset({'邓'}), frozenset({'格林', '布利'}), 0.7142857142857143), (frozenset({'布利'}), frozenset({'格林', '邓'}), 0.7142857142857143), (frozenset({'罪'}), frozenset({'格林', '德沃'}), 0.8333333333333334), (frozenset({'邓'}), frozenset({'格林', '德沃'}), 0.7142857142857143)]
# 用户5675125874
# 关联规则：
# [(frozenset({'作品'}), frozenset({'作者'}), 0.75), (frozenset({'吴京'}), frozenset({'地球'}), 0.75), (frozenset({'吴京'}), frozenset({'流浪'}), 0.75), (frozenset({'吴京'}), frozenset({'电影'}), 0.75), (frozenset({'故事'}), frozenset({'地球'}), 0.75), (frozenset({'地球'}), frozenset({'流浪'}), 0.9090909090909091), (frozenset({'流浪'}), frozenset({'地球'}), 1.0), (frozenset({'电影'}), frozenset({'地球'}), 0.8333333333333334), (frozenset({'故事'}), frozenset({'流浪'}), 0.75), (frozenset({'电影'}), frozenset({'流浪'}), 0.8333333333333334), (frozenset({'虫'}), frozenset({'铁'}), 1.0), (frozenset({'铁'}), frozenset({'虫'}), 0.9375), (frozenset({'吴京'}), frozenset({'流浪', '地球'}), 0.75), (frozenset({'故事'}), frozenset({'流浪', '地球'}), 0.75), (frozenset({'电影'}), frozenset({'流浪', '地球'}), 0.8333333333333334)]
